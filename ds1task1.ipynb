# %% [markdown]
# ## Dataset 1
# ### Preparation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns', 500)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Load Data

# %%
accepted = pd.read_csv('archive/accepted_2007_to_2018Q4.csv.gz')
rejected = pd.read_csv('archive/rejected_2007_to_2018Q4.csv.gz', )
# Out:
# C:\Users\Zenbook\AppData\Local\Temp\ipykernel_16332\1412068018.py:1: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   accepted = pd.read_csv('archive/accepted_2007_to_2018Q4.csv.gz')

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Dataset Structure

# %%
# Jumlah baris dan ko;om
accepted.shape,rejected.shape
# Out:
# ((2260701, 151), (27648741, 9))

# %%
# Tipe data
accepted.dtypes
# Out:
# id                                             object
# member_id                                     float64
# loan_amnt                                     float64
# funded_amnt                                   float64
# funded_amnt_inv                               float64
# term                                           object
# int_rate                                      float64
# installment                                   float64
# grade                                          object
# sub_grade                                      object
# emp_title                                      object
# emp_length                                     object
# home_ownership                                 object
# annual_inc                                    float64
# verification_status                            object
# issue_d                                        object
# loan_status                                    object
# ...

# %%
# hitung missing value
accepted.isnull().sum()
# Out:
# id                                                  0
# member_id                                     2260701
# loan_amnt                                          33
# funded_amnt                                        33
# funded_amnt_inv                                    33
# term                                               33
# int_rate                                           33
# installment                                        33
# grade                                              33
# sub_grade                                          33
# emp_title                                      167002
# emp_length                                     146940
# home_ownership                                     33
# annual_inc                                         37
# verification_status                                33
# issue_d                                            33
# loan_status                                        33
# ...

# %%
## list of columns with missing values
for col in accepted.columns:
    null_count = accepted[col].isnull().sum()  # Count of null values
    if null_count > 0:
        print(f"{col}:\t {null_count} null values")
# Out:
# member_id:	 2260701 null values
# loan_amnt:	 33 null values
# funded_amnt:	 33 null values
# funded_amnt_inv:	 33 null values
# term:	 33 null values
# int_rate:	 33 null values
# installment:	 33 null values
# grade:	 33 null values
# sub_grade:	 33 null values
# emp_title:	 167002 null values
# emp_length:	 146940 null values
# home_ownership:	 33 null values
# annual_inc:	 37 null values
# verification_status:	 33 null values
# issue_d:	 33 null values
# loan_status:	 33 null values
# pymnt_plan:	 33 null values
# url:	 33 null values
# desc:	 2134636 null values
# purpose:	 33 null values
# title:	 23359 null values
# zip_code:	 34 null values
# addr_state:	 33 null values
# dti:	 1744 null values
# delinq_2yrs:	 62 null values
# earliest_cr_line:	 62 null values
# fico_range_low:	 33 null values
# fico_range_high:	 33 null values
# inq_last_6mths:	 63 null values
# mths_since_last_delinq:	 1158535 null values
# mths_since_last_record:	 1901545 null values
# ...

# %%
# Lihat jenis data
list(set(accepted.dtypes.to_list()))
# Out:
# [dtype('O'), dtype('float64')]

# %%
# Subset data numerik
accepted_num = accepted.select_dtypes(include=['float64', 'int64'])
accepted_num.head()
# Out:
#    member_id  loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment  \
# 0        NaN     3600.0       3600.0           3600.0     13.99       123.03
# 1        NaN    24700.0      24700.0          24700.0     11.99       820.28
# 2        NaN    20000.0      20000.0          20000.0     10.78       432.66
# 3        NaN    35000.0      35000.0          35000.0     14.85       829.90
# 4        NaN    10400.0      10400.0          10400.0     22.45       289.91
#
#    annual_inc    dti  delinq_2yrs  fico_range_low  fico_range_high  \
# 0     55000.0   5.91          0.0           675.0            679.0
# 1     65000.0  16.06          1.0           715.0            719.0
# 2     63000.0  10.78          0.0           695.0            699.0
# 3    110000.0  17.06          0.0           785.0            789.0
# 4    104433.0  25.37          1.0           695.0            699.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# ...

# %%
accepted_num.describe()
# Out:
#        member_id     loan_amnt   funded_amnt  funded_amnt_inv      int_rate  \
# count        0.0  2.260668e+06  2.260668e+06     2.260668e+06  2.260668e+06
# mean         NaN  1.504693e+04  1.504166e+04     1.502344e+04  1.309283e+01
# std          NaN  9.190245e+03  9.188413e+03     9.192332e+03  4.832138e+00
# min          NaN  5.000000e+02  5.000000e+02     0.000000e+00  5.310000e+00
# 25%          NaN  8.000000e+03  8.000000e+03     8.000000e+03  9.490000e+00
# 50%          NaN  1.290000e+04  1.287500e+04     1.280000e+04  1.262000e+01
# 75%          NaN  2.000000e+04  2.000000e+04     2.000000e+04  1.599000e+01
# max          NaN  4.000000e+04  4.000000e+04     4.000000e+04  3.099000e+01
#
#         installment    annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  2.260668e+06  2.260664e+06  2.258957e+06  2.260639e+06    2.260668e+06
# mean   4.458068e+02  7.799243e+04  1.882420e+01  3.068792e-01    6.985882e+02
# ...

# %%
accepted_desc = accepted.select_dtypes(include=['object'])
accepted_desc.head()
# Out:
#          id        term grade sub_grade                    emp_title  \
# 0  68407277   36 months     C        C4                      leadman
# 1  68355089   36 months     C        C1                     Engineer
# 2  68341763   60 months     B        B4                 truck driver
# 3  66310712   60 months     C        C5  Information Systems Officer
# 4  68476807   60 months     F        F1          Contract Specialist
#
#   emp_length home_ownership verification_status   issue_d loan_status  \
# 0  10+ years       MORTGAGE        Not Verified  Dec-2015  Fully Paid
# 1  10+ years       MORTGAGE        Not Verified  Dec-2015  Fully Paid
# 2  10+ years       MORTGAGE        Not Verified  Dec-2015  Fully Paid
# 3  10+ years       MORTGAGE     Source Verified  Dec-2015     Current
# 4    3 years       MORTGAGE     Source Verified  Dec-2015  Fully Paid
#
#   pymnt_plan                                                url desc  \
# ...

# %%
accepted_num.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<Axes: title={'center': 'member_id'}>,
#         <Axes: title={'center': 'loan_amnt'}>,
#         <Axes: title={'center': 'funded_amnt'}>,
#         <Axes: title={'center': 'funded_amnt_inv'}>,
#         <Axes: title={'center': 'int_rate'}>,
#         <Axes: title={'center': 'installment'}>,
#         <Axes: title={'center': 'annual_inc'}>,
#         <Axes: title={'center': 'dti'}>,
#         <Axes: title={'center': 'delinq_2yrs'}>,
#         <Axes: title={'center': 'fico_range_low'}>,
#         <Axes: title={'center': 'fico_range_high'}>],
#        [<Axes: title={'center': 'inq_last_6mths'}>,
#         <Axes: title={'center': 'mths_since_last_delinq'}>,
#         <Axes: title={'center': 'mths_since_last_record'}>,
#         <Axes: title={'center': 'open_acc'}>,
#         <Axes: title={'center': 'pub_rec'}>,
#         <Axes: title={'center': 'revol_bal'}>,
#         <Axes: title={'center': 'revol_util'}>,
#         <Axes: title={'center': 'total_acc'}>,
# ...

# %%
Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
       'term', 'int_rate', 'installment', 'grade', 'sub_grade',
       ...
       'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
       'disbursement_method', 'debt_settlement_flag',
       'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
       'settlement_amount', 'settlement_percentage', 'settlement_term'],
      dtype='object', length=151)
# Out:
#   Cell In[14], line 3
#     ...
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### Data Cleaning
# 1. Mengidentifikasi nilai yang hilang dan menentukan strategi untuk menanganinya di
# masing-masing dataset.
# 2. Menghapus atau mengimputasi nilai yang hilang dengan metode yang sesuai.
# 3. Menyusun laporan singkat tentang alasan memilih metode tertentu.

# %%
rejected.head()

# %%
accepted.isnull().sum().sort_values(ascending=False)
